# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, datetime.time(0, 6, 17, 796000), 42, 'paid', None, None, 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2, datetime.time(0, 9, 46, 796000), 42, 'paid', None, None, 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (3, datetime.time(0, 12, 27, 796000), 42, 'paid', None, None, 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (4, datetime.time(0, 14, 52, 796000), 42, 'paid', None, None, 275, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(42, 'Harper', 'Barrett', 'M', 'paid'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (80, 'Tegan', 'Levine', 'F', 'paid')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, Decimal('305.162')),
#  ('SOUPIRU12A6D4FA1E1', 'Der Kleine Dompfaff', 'ARJIE2Y1187B994AB7', 0, Decimal('152.92036')),
#  ('SOWQTQZ12A58A7B63E', 'Streets On Fire (Explicit Album Version)', 'ARPFHN61187FB575F6', 0, Decimal('279.97995')),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, Decimal('75.67628')),
#  ('SONSKXP12A8C13A2C9', 'Native Soul', 'AR0IAWL1187B9A96D0', 2003, Decimal('197.19791'))]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', Decimal('40.79086'), Decimal('-73.96644')),
#  ('ARJIE2Y1187B994AB7', 'Line Renaud', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', Decimal('41.88415'), Decimal('-87.63241')),
#  ('AR558FS1187FB45658', '40 Grit', '', Decimal('NaN'), Decimal('NaN')),
#  ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', Decimal('8.4177'), Decimal('-80.11278'))]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.time(0, 6, 17, 796000), 0, '9', '45', '11', '2018', '4'),
#  (datetime.time(0, 9, 46, 796000), 0, '9', '45', '11', '2018', '4'),
#  (datetime.time(0, 12, 27, 796000), 0, '9', '45', '11', '2018', '4'),
#  (datetime.time(0, 14, 52, 796000), 0, '9', '45', '11', '2018', '4'),
#  (datetime.time(0, 17, 44, 796000), 0, '9', '45', '11', '2018', '4')]

# %%
#%sql SELECT songs.song_id AS songid, artists.artist_id AS artistid FROM songs JOIN artists ON songs.artist_id= artists.artist_id 
# %sql select * from artists where name = 'Minus The Bear'
#%sql select artist_id from artists;
#%sql select artist_id from songs WHERE artist_id like '%S%';
# %sql select * from songs where title = 'Just Dance'
# %sql select duration from songs
# %sql SELECT * FROM songplays WHERE artist_id IS NOT NULL
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(3546, datetime.time(21, 56, 47, 796000), 15, 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
#%sql SELECT DISTINCT start_time, COUNT (star_time) FROM time
# %sql SELECT DISTINCT start_time FROM time
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 6527 rows affected.
# [(datetime.time(14, 9, 41, 796000),),
#  (datetime.time(15, 32, 14, 796000),),
#  (datetime.time(10, 8, 46, 796000),),
#  (datetime.time(4, 43, 57, 796000),),
#  (datetime.time(4, 20, 48, 796000),),
#  (datetime.time(14, 28, 57, 796000),),
#  (datetime.time(16, 7, 13, 796000),),
#  (datetime.time(0, 54, 16, 796000),),
#  (datetime.time(22, 54, 53, 796000),),
#  (datetime.time(19, 41, 26, 796000),),
#  (datetime.time(4, 27, 16, 796000),),
#  (datetime.time(23, 51, 47, 796000),),
#  (datetime.time(18, 27, 16, 796000),),
#  (datetime.time(17, 14, 29, 796000),),
#  (datetime.time(16, 37, 27, 796000),),
#  (datetime.time(18, 46, 2, 796000),),
#  (datetime.time(11, 32, 4, 796000),),
#  (datetime.time(9, 45, 43, 796000),),
#  (datetime.time(7, 0, 7, 796000),),
#  (datetime.time(0, 52, 12, 796000),),
#  (datetime.time(18, 37, 38, 796000),),
#  (datetime.time(4, 6, 21, 796000),),
#  (datetime.time(4, 46, 3, 796000),),
# ...

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
